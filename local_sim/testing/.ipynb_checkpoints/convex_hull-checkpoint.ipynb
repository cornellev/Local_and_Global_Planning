# %%
def dist(point_a, point_b):
    return ((point_a[0] - point_b[0]) ** 2 + (point_a[1] - point_b[1]) ** 2)**.5

gen_circle = []

center_x = 10
center_y = 10
radius = 5

for i in range(center_x-radius-1, center_x+radius+1):
    for j in range(center_y-radius-1, center_y+radius+1):
        if dist((i, j), (center_x, center_y)) <= radius:
            gen_circle.append((i, j))

gen_circle_2 = []

center_x = 23
center_y = 22
radius = 7

for i in range(center_x-radius-1, center_x+radius+1):
    for j in range(center_y-radius-1, center_y+radius+1):
        if dist((i, j), (center_x, center_y)) <= radius:
            gen_circle_2.append((i, j))

# %%
import time
from IPython.display import clear_output

def convex_hull(points):
    """Computes the convex hull of a set of 2D points.

    Points: List of coordinate tuples
        Precondition: sorted by increasing x and then increasing y
    Output: a list of vertices of the convex hull in counter-clockwise order,
      starting from the vertex with the lexicographically smallest coordinates (smallest x then smallest y).
    
    Implements Andrew's monotone chain algorithm. O(n log n) complexity.
    """

    # If single point, just return the point
    if len(points) <= 1:
        return points

    # 2D cross product of OA and OB vectors, i.e. z-component of their 3D cross product.
    # Returns a positive value, if OAB makes a counter-clockwise turn,
    # negative for clockwise turn, and zero if the points are collinear.
    # Effectively, checks if b makes an "outward/convex" turn
    def cross(o, a, b):
        return (a[0] - o[0]) * (b[1] - o[1]) - (a[1] - o[1]) * (b[0] - o[0])


    # Process:
    #   Lower hull starts at leftmost position (lowest x,y) and then moves to increasing coordinates.
    #     If a coordinate makes an outward/convex turn, that means it needs to be added to the outside of the hull
    #     Otherwise, the coordinate already rests inside the hull.
    #   Upper hull, same as lower hull, but starts at rightmost position (highest x,y)

    # Build lower hull 

    frame_count = 0
    
    lower = []
    upper = []
    for p in points:
        while len(lower) >= 2 and cross(lower[-2], lower[-1], p) <= 0:
            lower.pop()
            # time.sleep(.005)
            # clear_output(wait=True)
            # plot_points(points, lower[:-1] + upper[:-1])
        lower.append(p)
        frame_count = plot_points(points, lower[:-1] + upper[:-1], frame_count)
        # time.sleep(.005)
        # clear_output(wait=True)

    # Build upper hull
    for p in reversed(points):
        while len(upper) >= 2 and cross(upper[-2], upper[-1], p) <= 0:
            upper.pop()
            # time.sleep(.005)
            # clear_output(wait=True)
            # plot_points(points, lower[:-1] + upper[:-1])
        
        upper.append(p)
        # time.sleep(.005)
        # clear_output(wait=True)
        frame_count = plot_points(points, lower[:-1] + upper[:-1], frame_count)
        print("plotted")

    # Concatenation of the lower and upper hulls gives the convex hull.
    # Last point of each list is omitted because it is repeated at the beginning of the other list.

    print("done")
    return lower[:-1] + upper[:-1]
    
# points = [(2, 2), (3, 3), (4, 4), (2, 2.5), (2.25, 2.3)]
points = gen_circle
points_hull = convex_hull(points)
# Out:
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# plotted
# ...

# %%
import matplotlib.pyplot as plt

def plot_points(points, convex_hull):
    """
    Plot the points and the convex hull.
    """
    # Extract x and y coordinates of points and convex hull
    points_x = [point[0] for point in points]
    points_y = [point[1] for point in points]

    convex_hull_x = [point[0] for point in convex_hull]
    convex_hull_y = [point[1] for point in convex_hull]

    # Plot points and convex hull
    plt.figure(figsize=(8, 6))
    plt.plot(points_x, points_y, 'bo', label='Points')
    try:
        plt.plot(convex_hull_x + [convex_hull_x[0]], convex_hull_y + [convex_hull_y[0]], 'r-', label='Convex Hull')
    except:
        pass
    plt.title('Convex Hull')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
from IPython.display import HTML

# Create a figure and axis
fig, ax = plt.subplots()

# Create an empty plot object
line, = ax.plot([], [], lw=2)

# Define the initialization function
def init():
    line.set_data([], [])
    return line,

# Define the animation function
def animate(i):
    x = np.linspace(0, 2*np.pi, 100)
    y = np.sin(x + 0.1 * i)
    line.set_data(x, y)
    return line,

# Create the animation
ani = FuncAnimation(fig, animate, init_func=init, frames=100, interval=50, blit=True)

HTML(anim.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 25
#      22     return line,
#      24 # Create the animation
# ---> 25 ani = FuncAnimation(fig, animate, init_func=init, frames=100, interval=50, blit=True)
#      27 HTML(anim.to_jshtml())
#
# NameError: name 'FuncAnimation' is not defined

# %%
import matplotlib.pyplot as plt
import os

def plot_points(points, convex_hull, frame_count=0):
    """
    Plot the points and the convex hull and save each frame to a GIF.
    """
    # Extract x and y coordinates of points and convex hull
    points_x = [point[0] for point in points]
    points_y = [point[1] for point in points]

    convex_hull_x = [point[0] for point in convex_hull]
    convex_hull_y = [point[1] for point in convex_hull]

    # Plot points and convex hull
    plt.figure(figsize=(8, 6))
    plt.plot(points_x, points_y, 'bo', label='Points')
    try:
        plt.plot(convex_hull_x + [convex_hull_x[0]], convex_hull_y + [convex_hull_y[0]], 'r-', label='Convex Hull')
    except:
        pass
    plt.title('Convex Hull')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend()
    plt.grid(True)
    
    # Save the figure as a frame in a GIF
    gif_folder = "frames_2"
    if not os.path.exists(gif_folder):
        os.makedirs(gif_folder)
    frame_path = os.path.join(gif_folder, f"frame_{frame_count}.png")
    plt.savefig(frame_path)
    plt.close()
    
    # Increment frame count for the next frame
    frame_count += 1

    return frame_count

# %%
import os
import imageio

def create_gif(frames_folder, gif_path, duration=2):
    """
    Create a GIF from frames in the frames folder.
    """
    # Get all file names in the frames folder
    frames = [f for f in os.listdir(frames_folder) if os.path.isfile(os.path.join(frames_folder, f))]
    frames.sort(key=lambda x: int(x.split('_')[1].split('.')[0]))  # Sort by frame number

    print(frames)

    # Read frames and add them to GIF
    images = []
    for frame in frames:
        frame_path = os.path.join(frames_folder, frame)
        images.append(imageio.imread(frame_path))

    # Save the frames as a GIF
    imageio.mimsave(gif_path, images, duration=duration, loop=0)

# Define the folder containing frames and path to save the GIF
frames_folder = "frames_2"
gif_path = "animation_2.gif"

# Create the GIF
create_gif(frames_folder, gif_path)

print("GIF created successfully!")
# Out:
# ['frame_0.png', 'frame_1.png', 'frame_2.png', 'frame_3.png', 'frame_4.png', 'frame_5.png', 'frame_6.png', 'frame_7.png', 'frame_8.png', 'frame_9.png', 'frame_10.png', 'frame_11.png', 'frame_12.png', 'frame_13.png', 'frame_14.png', 'frame_15.png', 'frame_16.png', 'frame_17.png', 'frame_18.png', 'frame_19.png', 'frame_20.png', 'frame_21.png', 'frame_22.png', 'frame_23.png', 'frame_24.png', 'frame_25.png', 'frame_26.png', 'frame_27.png', 'frame_28.png', 'frame_29.png', 'frame_30.png', 'frame_31.png', 'frame_32.png', 'frame_33.png', 'frame_34.png', 'frame_35.png', 'frame_36.png', 'frame_37.png', 'frame_38.png', 'frame_39.png', 'frame_40.png', 'frame_41.png', 'frame_42.png', 'frame_43.png', 'frame_44.png', 'frame_45.png', 'frame_46.png', 'frame_47.png', 'frame_48.png', 'frame_49.png', 'frame_50.png', 'frame_51.png', 'frame_52.png', 'frame_53.png', 'frame_54.png', 'frame_55.png', 'frame_56.png', 'frame_57.png', 'frame_58.png', 'frame_59.png', 'frame_60.png', 'frame_61.png', 'frame_62.png',
# ...
